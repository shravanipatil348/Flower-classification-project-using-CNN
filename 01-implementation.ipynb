# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
train_path = "train"
test_path = "test"

# %%
import os

print(os.listdir("Flower Classification Dataset"))
# Out:
# ['.ipynb_checkpoints', 'test', 'train']

# %%
print(train_path)
print(test_path)
# Out:
# train
# test

# %%
train_path = "Flower Classification Dataset/train"
test_path = "Flower Classification Dataset/test"

print(train_path)
print(test_path)
# Out:
# Flower Classification Dataset/train
# Flower Classification Dataset/test

# %%
target_size=(64,64)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255
)

test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
train_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)

test_data = test_datagen.flow_from_directory(
    test_path,
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 140 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Input(shape=(64,64,3)),
    Conv2D(16,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(64,activation='relu'),
    Dense(3,activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=5
)
# Out:
# Epoch 1/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 419ms/step - accuracy: 0.4714 - loss: 0.9706 - val_accuracy: 0.5333 - val_loss: 0.6627
# Epoch 2/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 281ms/step - accuracy: 0.5214 - loss: 0.7775 - val_accuracy: 0.6000 - val_loss: 0.6475
# Epoch 3/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step - accuracy: 0.6857 - loss: 0.6152 - val_accuracy: 0.5667 - val_loss: 0.6458
# Epoch 4/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - accuracy: 0.6786 - loss: 0.5885 - val_accuracy: 0.7500 - val_loss: 0.5861
# Epoch 5/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 0.7357 - loss: 0.5190 - val_accuracy: 0.7833 - val_loss: 0.5294

# %%
print(train_data.image_shape)
print(model.input_shape)
# Out:
# (64, 64, 3)
# (None, 64, 64, 3)

# %%
model.save("flower_model.keras")
