# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
train_path = "train"
test_path = "test"

# %%
import os

print(os.listdir("Flower Classification Dataset"))
# Out:
# ['.ipynb_checkpoints', 'test', 'train']

# %%
print(train_path)
print(test_path)
# Out:
# train
# test

# %%
train_path = "Flower Classification Dataset/train"
test_path = "Flower Classification Dataset/test"

print(train_path)
print(test_path)
# Out:
# Flower Classification Dataset/train
# Flower Classification Dataset/test

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_data = ImageDataGenerator(rescale=1./255).flow_from_directory(
    train_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary'
)

test_data = ImageDataGenerator(rescale=1./255).flow_from_directory(
    test_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 140 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_data = ImageDataGenerator(rescale=1./255).flow_from_directory(
    train_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical'   # ✅
)

test_data = ImageDataGenerator(rescale=1./255).flow_from_directory(
    test_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical'   # ✅
)
# Out:
# Found 140 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=5
)
# Out:
# Epoch 1/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 0.5929 - loss: 1.1976 - val_accuracy: 0.4667 - val_loss: 0.7244
# Epoch 2/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7429 - loss: 0.5281 - val_accuracy: 0.8333 - val_loss: 0.4914
# Epoch 3/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.8714 - loss: 0.3647 - val_accuracy: 0.8667 - val_loss: 0.3951
# Epoch 4/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 659ms/step - accuracy: 0.9071 - loss: 0.2646 - val_accuracy: 0.8333 - val_loss: 0.4282
# Epoch 5/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 682ms/step - accuracy: 0.8571 - loss: 0.2655 - val_accuracy: 0.8500 - val_loss: 0.3741

# %%
model.save("flower_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
